# %% [markdown]
# # ЛР2. Двойственность в линейном программировании. Вариант 1.

# %% [markdown]
# ## Выполнил: студент группы ИУ8-34, Александров Алексей

# %% [markdown]
# ### Подключаем simplex.py, написанный нами.
# #### Выводим условие задачи.

# %%
# Copyright 2020 Alexey Alexandrov <sks2311211@yandex.ru>

"""
Лабораторная работа № 2
Двойственность в линейном программировании.
Цель: Изучить постановку двойственной задачи (ДЗ);
ЛП по прямой задаче (ПЗ); получить навыки решения соответствующей
ДЗ по прямой задаче.

Вариант 1.
"""

from simplex import *
import dual_problem

if __name__ == '__main__':
    print('ЛР2 по МО. "ДЗ в линейном программировании.', )

    print("\tПрямая задача ЛП:")
    problem = Simplex("input_data.json")
    print(problem)
# Out:
# ЛР2 по МО. "ДЗ в линейном программировании.
# 	Прямая задача ЛП:
# Условие задачи:
# ------------------------------------------------------------
# Найти вектор x = (x1,x2,..., xn)^T как решение след. задачи:
# F = сx -> max,
# Ax <= b,
# x1,x2, ..., xn >= 0
# C = [-5 -6 -4],
# A =
# [[1.  1.  1. ]
#  [1.  3.  0. ]
#  [0.  0.5 4. ]],
# b^T = [7 8 6].
# ------------------------------------------------------------

# %% [markdown]
# ### Находим опорное и оптимальное решение прямой задачи.

# %%
# Находим опорное решение.
problem.reference_solution()
# Находим оптимальное решение.
problem.optimal_solution()
# Out:
# Процесс решения:
# 1) Поиск опорного решения:
# Исходная симплекс-таблица:
#          Si0    x4    x5    x3
#     x1   6.5   1.5  -0.5   1.5
#     x2   0.5  -0.5   0.5  -0.5
#     x6   5.8   0.2  -0.2   4.2
#     F   35.5  -4.5  -0.5  -0.5
#
# -----------
# Опорное решение найдено!
# x4 = x5 = x3 = 0, x1 =  6.5, x2 =  0.5, x6 =  5.8,
# Целевая функция: F = 35.5
# -----------
# 2) Поиск оптимального решения:
# -----------
# Оптимальное решение найдено!
# x4 = x5 = x3 = 0, x1 =  6.5, x2 =  0.5, x6 =  5.8,
# Целевая функция: F = -35.5
# -----------

# %% [markdown]
# ### Находим оптимальное решение задачи.

# %%
print("\tДвойственная задача ЛП:")
dual_p = dual_problem.DualProblem("input_data.json")

# Находим опорное решение.
dual_p.reference_solution()
# Находим оптимальное решение.
dual_p.optimal_solution()
# Out:
# 	Двойственная задача ЛП:
# ------------------------------------------------------------
# Ф = b^Tx -> min,
# A^Tx >= c^T,
# x1,x2, ..., xn >= 0
# C^T = [7 8 6],
# A^T =
# [[1.  1.  0. ]
#  [1.  3.  0.5]
#  [1.  0.  4. ]],
# b = [5 6 4].
# ------------------------------------------------------------
# Процесс решения:
# 1) Поиск опорного решения:
# Исходная симплекс-таблица:
#          Si0    x1    x2    x3
#     x4  -5.0  -1.0  -1.0  -0.0
#     x5  -6.0  -1.0  -3.0  -0.5
#     x6  -4.0  -1.0  -0.0  -4.0
#     F    0.0  -7.0  -8.0  -6.0
#
# Разрешающая строка: x5
# Разрешающий столбец: x2
#          Si0    x6    x2    x3
#     x4  -1.0  -1.0  -1.0   4.0
#     x5  -2.0  -1.0  -3.0   3.5
#     x1   4.0  -1.0   0.0   4.0
#     F   28.0  -7.0  -8.0  22.0
#
# Разрешающая строка: x5
# Разрешающий столбец: Si0
#          Si0    x4    x2    x3
#     x6   1.0  -1.0   1.0  -4.0
#     x5  -1.0  -1.0  -2.0  -0.5
#     x1   5.0  -1.0   1.0   0.0
#     F   35.0  -7.0  -1.0  -6.0
#
# Разрешающая строка: x5
# Разрешающий столбец: x4
#          Si0    x5    x2    x3
#     x6   2.0  -1.0   3.0  -3.5
#     x4   1.0  -1.0   2.0   0.5
#     x1   6.0  -1.0   3.0   0.5
#     F   42.0  -7.0  13.0  -2.5
#
# -----------
# Опорное решение найдено!
# x5 = x2 = x3 = 0, x6 =  2.0, x4 =  1.0, x1 =  6.0,
# Целевая функция: F = 42.0
# -----------
# 2) Поиск оптимального решения:
# Разрешающая строка: x1
# Разрешающий столбец: x5
#          Si0    x5    x4    x3
#     x6   0.5   0.5  -1.5  -4.2
#     x2   0.5  -0.5   0.5   0.2
#     x1   4.5   0.5  -1.5  -0.2
#     F   35.5  -0.5  -6.5  -5.8
#
# -----------
# Оптимальное решение найдено!
# x5 = x4 = x3 = 0, x6 =  0.5, x2 =  0.5, x1 =  4.5,
# Целевая функция: F = 35.5
# -----------

# %% [markdown]
# ## Итак оптимальное решение:
# -----------
# x5 = x4 = x3 = 0, x6 =  0.5, x2 =  0.5, x1 =  4.5,
# Целевая функция: F = 35.5
#
# ### **Целевая функция: F = 35.5**
#
# -----------
